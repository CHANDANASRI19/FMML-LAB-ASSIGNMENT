# %% [markdown]
# <a href="https://colab.research.google.com/github/CHANDANASRI19/FMML-LAB-ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 12:30:08--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   211MB/s    in 0.3s
#
# 2024-03-28 12:30:10 (211 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 28407  1706.05206v1  Convolutional neural networks (CNNs) have mass...    cs
# 9084   cs/0008019v1  The growing problem of unsolicited bulk e-mail...    cs
# 40578   0812.3147v1  We investigate the performance of a simple sig...    cs
# 22283  1511.07367v1  Latent variable time-series models are among t...  stat
# 35640   1011.4632v1  This paper discusses the topic of dimensionali...    cs
# ...             ...                                                ...   ...
# 37755  1802.09728v2  The changes in user preferences can originate ...    cs
# 36257  1604.07322v2  Among the various means to evaluate the qualit...    cs
# 11773  1611.09827v2  This paper introduces a new large-scale music ...  stat
# 37617  1711.04013v1  In recent years, there has been an increasing ...    cs
# 24555   1407.4206v1  The light field camera is useful for computer ...    cs
#
#                                                    title  year  \
# 28407    Dynamic Filters in Graph Convolutional Networks  2017
# 9084   An Experimental Comparison of Naive Bayesian a...  2000
# 40578  Comparison of Binary Classification Based on S...  2008
# 22283  Black box variational inference for state spac...  2015
# 35640        Random Projections for $k$-means Clustering  2010
# ...                                                  ...   ...
# 37755  Modelling and Analysis of Temporal Preference ...  2018
# 36257  Predictive No-Reference Assessment of Video Qu...  2016
# 11773            Learning Features of Music from Scratch  2016
# 37617               Stream Reasoning in Temporal Datalog  2017
# 24555  Mobile Camera Array Calibration for Light Fiel...  2014
#
#                                                 keywords
# 28407  [convolutional, massively, recognition, ubiqui...
# 9084   [unsolicited, generated, constructed, alternat...
# 40578  [investigate, performance, comparison, experim...
# 22283  [statistics, advantage, structure, observation...
# 35640  [discusses, dimensionality, reduction, cluster...
# ...                                                  ...
# 37755  [preferences, originate, substantial, personal...
# 36257  [reference, computation, algorithms, candidate...
# 11773  [introduces, supervision, evaluation, classica...
# 37617  [increasing, extending, traditional, processin...
# 24555  [applications, calibration, essential, applica...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 28407    [convolutional, massively, recognition, ubiqui...
# 9084     [unsolicited, generated, constructed, alternat...
# 40578    [investigate, performance, comparison, experim...
# 22283    [statistics, advantage, structure, observation...
# 35640    [discusses, dimensionality, reduction, cluster...
#                                ...
# 30557    [important, grapevine, phenotyping, monitoring...
# 16352    [contextual, incorporate, discourse, informati...
# 6201     [dimension, reduction, approaches, projections...
# 3723     [equivalence, computing, polynomial, recursive...
# 22489    [variational, inference, algorithms, approxima...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8863 words.
# Out of those 4565 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bf33188e-fcd9-44ed-ba41-e1caccc1dabc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf33188e-fcd9-44ed-ba41-e1caccc1dabc")) {                    Plotly.newPlot(                        "bf33188e-fcd9-44ed-ba41-e1caccc1dabc",                        [{"x":["convolution","ubiquitous","recognition","significantly","experimental","rectangular","generalize","architecture","supervised","classification","improving","evaluations","organized","formulation","correspondence","approaches","convolutional","massively","molecular","naturally","collection","experiments","automatically","sensitive","generated","appropriate","available","constructed","performance","classifier","alternative","lemmatization","contributing","encrypted","investigating","filtering","attribute","introduce","comparison","benchmarks","geometric","comparing","optimized","functions","microarray","benchmark","developed","classifiers","potential","synthetic","demonstrate","investigate","conjugate","variational","meaningful","structure","approximate","intuition","posteriors","structured","consequently","intractable","inference","particular","developments","technique","importantly","estimates","statistics","observations","procedures","exception","dynamical","interestingly","posterior","nonlinear","advantage","correlation","generative","stochastic","reduction","dimensionality","partition","multiplying","discusses","implementation","theoretical","projections","clustering","dimensions","projected","projection","numerical","preserved","probability","information","specifically","techniques","discovery","indicators","increased","automated","characteristics","laboratory","inferences","therefore","epidemiology","extracted","considerable","extraction","demographics","representations","individuals","understand","surveillance","population","difficult","corresponding","dependency","distributed","forecasts","automating","monitoring","annotated","epidemiological","availability","inferring","confirmed","construction","supervision","responses","generation","mechanism","guarantees","different","stability","coordinate","distribution","effectiveness","presented","repulsive","segmentation","balancing","discriminative","considerably","exploited","represent","outperforms","descriptors","dimensional","direction","introduced","computational","recognizing","calculated","challenging","furthermore","efficient","components","correlations","representation","classified","relations","considered","activities","personalized","rehabilitation","incomplete","qualitative","formulate","prediction","measurements","directions","conducting","framework","recommender","collected","predicting","imputation","collaborative","feasibility","retrieval","methodology","extracting","minimization","extension","knowledge","unsatisfactory","curricula","typically","exploiting","competing","convergence","extensively","additionally","dictionaries","evaluated","curriculum","algorithmic","iterative"],"y":[45,22,374,283,374,2,67,245,211,491,106,66,24,83,29,419,377,7,6,65,75,587,180,46,196,86,277,51,855,138,98,3,8,1,16,57,27,330,129,95,64,74,46,203,4,209,211,120,156,144,573,153,7,57,54,338,115,18,6,105,33,26,206,261,25,259,33,67,55,70,38,4,17,15,49,53,97,83,133,136,103,53,18,3,21,117,172,21,130,47,21,51,74,12,163,737,168,385,53,10,33,87,69,10,10,176,1,96,40,144,2,241,36,60,24,36,166,123,52,108,6,4,39,80,3,28,24,10,66,79,33,158,121,55,746,36,22,221,248,184,2,175,18,95,31,31,104,248,52,166,67,128,288,31,31,273,152,393,104,31,356,26,92,131,33,14,3,26,63,50,241,60,36,13,546,14,86,81,4,23,37,116,60,70,67,65,343,2,2,107,67,29,132,46,68,16,133,9,48,67],"type":"bar"},{"x":["convolution","ubiquitous","recognition","significantly","exper ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4565,), (4565, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8166666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>to</span> <span style=''>Prune</span> <span style=''>Filters</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.6180257510729614);'>Convolutional</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Many</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>computer</span> <span style=''>vision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>use</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.6180257510729614);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>(CNNs)</span> <span style=''>as</span> <span style=''>basic</span> <span style=''>building</span> <span style=''>blocks</span> <span style=''>These</span> <span style=''>CNNs</span> <span style=''>are</span> <span style=''>known</span> <span style=''>for</span> <span style=''>their</span> <span style=''>huge</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>redundancy</span> <span style=''>in</span> <span style=''>weights</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>tremendous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>resource</span> <span style=''>consumptions</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>simplify</span> <span style=''>and</span> <span style=''>speed</span> <span style=''>up</span> <span style=''>these</span> <span style=''>CNNs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>try</span> <span style=''>and</span> <span style=''>learn</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>train</span> <span style=''>pruning</span> <span style=''>agents</span> <span style=''>that</span> <span style=''>remove</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unnecessary</span> <span style=''>CNN</span> <span style=''>filters</span> <span style=''>in</span> <span style=''>a</span> <span style=''>data</span> <span style=''>driven</span> <span style=''>way</span> <span style=''>With</span> <span style=''>the</span> <span style=''>help</span> <span style=''>of</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>reward</span> <span style=''>function</span> <span style=''>our</span> <span style=''>agents</span> <span style=''>removes</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significant</span> <span style=''>number</span> <span style=''>of</span> <span style=''>filters</span> <span style=''>in</span> <span style=''>CNNs</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maintaining</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>at</span> <span style=''>a</span> <span style=''>desired</span> <span style=''>level</span> <span style=''>Moreover</span> <span style=''>this</span> <span style=''>method</span> <span style=''>provides</span> <span style=''>an</span> <span style=''>easy</span> <span style=''>control</span> <span style=''>of</span> <span style=''>the</span> <span style=''>tradeoff</span> <span style=''>between</span> <span style=''>network</span> <span style='background-c ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Perfect</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Blockmodel</span> <span style=''>Graphs</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Adjacency</span> <span style=''>Spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Embedding</span> <br/><br/><span style=''>Vertex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>blockmodel</span> <span style=''>graph</span> <span style=''>has</span> <span style=''>wide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applicability</span> <span style=''>and</span> <span style=''>has</span> <span style=''>been</span> <span style=''>the</span> <span style=''>subject</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensive</span> <span style=''>research</span> <span style=''>In</span> <span style=''>thispaper</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>short</span> <span style=''>proof</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adjacency</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>perfect</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>blockmodel</span> <span style=''>and</span> <span style=''>the</span> <span style=''>degree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>blockmodel</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analogous</span> <span style=''>result</span> <span style=''>for</span> <span style=''>the</span> <span style=''>more</span> <span style=''>general</span> <span style=''>random</span> <span style=''>dot</span> <span style=''>product</span> <span style=''>graph</span> <span style=''>model</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.34121929026387604);'>Information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style=''>limits</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>learning</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.34121929026387604);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style=''>limits</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>(BNs)</span> <span style=''>on</span> <span style=''>discrete</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.30917874396135275);'>variables</span> <span style=''>from</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>number</span> <span style=''>of</span> <span style=''>samples</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>minimum</span> <span style=''>number</span> <span style=''>of</span> <span style=''>samples</span> <span style=''>required</span> <span style=''>by</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>to</span> <span style=''>recover</span> <span style=''>the</span> <span style=''>correct</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>grows</span> <span style=''>as</span> <span style=''>Omega(m)</span> <span style=''>and</span> <span style=''>Omega(k</span> <span style=''>log</span> <span style=''>m</span> <span style=''>(k2m))</span> <span style=''>for</span> <span style=''>non</span> <span style=''>sparse</span> <span style=''>and</span> <span style=''>sparse</span> <span style=''>BNs</span> <span style='background-color:rgba(0, 255, 0, 0.41880341880341887);'>respectively</span> <span style=''>where</span> <span style=''>m</span> <span style=''>is</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.30917874396135275);'>variables</span> <span style=''>and</span> <span style=''>k</span> <span style=''>is</span> <span style=''>the</span> <span style=''>maximum</span> <span style=''>number</span> <span style=''>of</span> <span style=''>parents</span> <span style=''>per</span> <span style=''>node</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>recipe</span> <span style=''>based</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Fanos</span> <span style='background-color:rgba(255, 0, 0, 0.44);'>inequality</span> <span style=''>to</span> <span style=''>obtain</span> <span style='background-color:rgba(0, 255, 0, 0.34121929026387604);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style=''>limits</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>recovery</span> <span style=''>for</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>family</span> <span style=''>BN</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>Nested</span> <span style=''>Chinese</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Restaurant</span> <span style=''>Process</span> <span style=''>Topic</span> <span style=''>Models</span> <br/><br/><span style=''>Nested</span> <span style=''>Chinese</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Restaurant</span> <span style=''>Process</span> <span style=''>(nCRP)</span> <span style=''>topic</span> <span style=''>models</span> <span style=''>are</span> <span style=''>powerful</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>Bayesian</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>extract</span> <span style=''>a</span> <span style=''>topic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchy</span> <span style=''>from</span> <span style=''>a</span> <span style=''>given</span> <span style=''>text</span> <span style=''>corpus</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determined</span> <span style=''>by</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style=''>Latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Allocation</span> <span style=''>(hLDA)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>instance</span> <span style=''>of</span> <span style=''>nCRP</span> <span style=''>topic</span> <span style=''>models</span> <span style=''>However</span> <span style=''>hLDA</span> <span style=''>has</span> <span style=''>only</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluated</span> <span style=''>at</span> <span style=''>small</span> <span style=''>scale</span> <span style=''>because</span> <span style=''>the</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collapsed</span> <span style=''>Gibbs</span> <span style=''>sampling</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instantiated</span> <span style=''>weight</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>either</span> <span style=''>are</span> <span style=''>not</span> <span style=''>scalable</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sacrifice</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>quality</span> <span style=''>with</span> <span style=''>mean</span> <span style=''>field</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>Moreover</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dynamically</span> <span style=''>growing</span> <span style=''>count</span> <span style=''>matrices</span> <span style=''>and< ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06188118811881188)
# 	automatic (0.07213578500707214)
# 	experimental (0.13224893917963224)
# 	knowledge (0.12128712871287128)
# 	architecture (0.08663366336633663)
# 	detection (0.1173974540311174)
# 	different (0.2637906647807638)
# 	information (0.2606082036775106)
# 	recognition (0.13224893917963224)
# 	convolutional (0.1333097595473833)
#
# Some Statistics words are:
# 	variables (0.1374239350912779)
# 	stochastic (0.13640973630831643)
# 	theoretical (0.15212981744421908)
# 	statistical (0.1643002028397566)
# 	estimation (0.17799188640973632)
# 	distribution (0.1947261663286004)
# 	algorithm (0.38995943204868155)
# 	dimensional (0.19523326572008112)
# 	inference (0.2099391480730223)
# 	regression (0.17596348884381338)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="78618607-ff03-4bf1-85eb-216e3c1f14b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78618607-ff03-4bf1-85eb-216e3c1f14b1")) {                    Plotly.newPlot(                        "78618607-ff03-4bf1-85eb-216e3c1f14b1",                        [{"x":["convolution","ubiquitous","recognition","significantly","experimental","rectangular","generalize","architecture","supervised","classification","improving","evaluations","organized","formulation","correspondence","approaches","convolutional","massively","molecular","naturally","collection","experiments","automatically","sensitive","generated","appropriate","available","constructed","performance","classifier","alternative","lemmatization","contributing","encrypted","investigating","filtering","attribute","introduce","comparison","benchmarks","geometric","comparing","optimized","functions","microarray","benchmark","developed","classifiers","potential","synthetic","demonstrate","investigate","conjugate","variational","meaningful","structure","approximate","intuition","posteriors","structured","consequently","intractable","inference","particular","developments","technique","importantly","estimates","statistics","observations","procedures","exception","dynamical","interestingly","posterior","nonlinear","advantage","correlation","generative","stochastic","reduction","dimensionality","partition","multiplying","discusses","implementation","theoretical","projections","clustering","dimensions","projected","projection","numerical","preserved","probability","information","specifically","techniques","discovery","indicators","increased","automated","characteristics","laboratory","inferences","therefore","epidemiology","extracted","considerable","extraction","demographics","representations","individuals","understand","surveillance","population","difficult","corresponding","dependency","distributed","forecasts","automating","monitoring","annotated","epidemiological","availability","inferring","confirmed","construction","supervision","responses","generation","mechanism","guarantees","different","stability","coordinate","distribution","effectiveness","presented","repulsive","segmentation","balancing","discriminative","considerably","exploited","represent","outperforms","descriptors","dimensional","direction","introduced","computational","recognizing","calculated","challenging","furthermore","efficient","components","correlations","representation","classified","relations","considered","activities","personalized","rehabilitation","incomplete","qualitative","formulate","prediction","measurements","directions","conducting","framework","recommender","collected","predicting","imputation","collaborative","feasibility","retrieval","methodology","extracting","minimization","extension","knowledge","unsatisfactory","curricula","typically","exploiting","competing","convergence","extensively","additionally","dictionaries","evaluated","curriculum","algorithmic","iterative","guaranteed","frameworks","generating","strengths","algorithm","connection","directlingam","estimation","identifies","structural","gaussianity","parameters","algorithms","variables","conventional","continuous","evaluation","washington","detection","recordings","displaying","conference","challenges","benchmarking","automatic","expressions","conjunction","addressing","occurrence","addresses","assessing","conditions","challenge","intensity","limitation","expression","practitioners","technology","phenomenon","literature","interaction","researchers","explanatory","psychology","themselves","behavioural","designers","explainable","ourselves","decisions","cognitive","emergence","philosophy","implement","unmodified","generalization","sugge ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	integrands
# 	undersampled
# 	hypernetwork
# 	hypernetworks
# 	asymmetries
# 	correntropy
# 	stationarities
# 	forecasters
# 	autoencoding
# 	initializations
# 	temperatures
# 	renewable
# 	assimilating
# 	assimilation
# 	assimilated
# 	covariances
# 	sparsistency
# 	heckerman
# 	reassignment
# 	inductively
# Some words which never appear in Statistics papers:
# 	lemmatization
# 	demographics
# 	epidemiological
# 	washington
# 	ourselves
# 	impacting
# 	conversational
# 	accordance
# 	syntactic
# 	marginalizes
# 	daubechies
# 	passively
# 	navigational
# 	localizing
# 	achromatic
# 	multitasking
# 	referenced
# 	metaheuristics
# 	lexicographic
# 	crossover

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.044603440401888e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7741666666666667
